# %% [markdown]
# <a href="https://colab.research.google.com/github/Brice-Harper/Brice-Harper/blob/main/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titre 1

# %%
# Assign values to variables a and b
a = 10
b = 5

# Perform an operation using a and b
sum_of_a_and_b = a + b

# Print the result
print(f"The value of a is: {a}")
print(f"The value of b is: {b}")
print(f"The sum of a and b is: {sum_of_a_and_b}")
# Out:
# The value of a is: 10
# The value of b is: 5
# The sum of a and b is: 15
